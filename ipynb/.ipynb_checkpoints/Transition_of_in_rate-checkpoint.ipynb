# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import sys
#"".."からimportできなかったため，パスを追加．
module_path = os.path.abspath(os.path.join('../analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

import analysis_black_jack as abj

# %% [markdown]
# ## ブラックジャックの実行（30000000回）

# %%
# %%time
a = abj.MakeDataFrame(300000, 5, True, 100)
df = a.main()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 300000/300000 [00:21<00:00, 14240.04it/s]
# DataFrameを作成
# スプリット列を追加
# get_coin列の追加
# Wall time: 35.2 s

# %% [markdown]
# ### 勝率の推移．勝率は収束していく

# %%
b = abj.AnalysisDf(df)
j, k = b.win_percentage(split=1000, plot=True)
# Out:
# 49.471%
