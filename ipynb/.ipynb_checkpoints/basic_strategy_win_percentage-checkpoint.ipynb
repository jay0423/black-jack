# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import sys
#"".."からimportできなかったため，パスを追加．
module_path = os.path.abspath(os.path.join('../analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

import analysis_black_jack as abj

# %%
# %%time
a = abj.MakeDataFrame(10000000, 5, True, 50)
df = a.main()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 10000000/10000000 [04:17<00:00, 38896.74it/s]
# DataFrameを作成
# Wall time: 4min 40s

# %%
#独自のアルゴリズムにおける勝率の算出
b = abj.WinPercentage(df)
bs = b.basic_strategy_win_percentage(win_coin=True)

# %%
#単純な勝率の算出
b = abj.WinPercentage(df)
bs = b.basic_strategy_win_percentage(win_coin=False)
