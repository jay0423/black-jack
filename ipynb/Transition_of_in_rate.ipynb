# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import sys
#"".."からimportできなかったため，パスを追加．
module_path = os.path.abspath(os.path.join('../analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

import analysis_black_jack as abj
import make_dataframe as md

# %% [markdown]
# ## ブラックジャックの実行（40000000回）

# %%
# %%time
a = md.MakeDataFrame(100000, 6, True, 50)
df = a.main()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:02<00:00, 37491.45it/s]
# DataFrameを作成
# Wall time: 3.23 s

# %% [markdown]
# ### 勝率の推移．勝率は収束していく

# %%
# %%time
b = abj.WinPercentage(df)
j, k = b.win_percentage(split=300, plot=True)
# Out:
# 49.68218%
# Wall time: 9.14 s

# %% [markdown]
# ## ブラックジャックの実行（40000000回）

# %%
# %%time
a = md.MakeDataFrame(100000, 5, True, 100)
df = a.main()
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 40000000/40000000 [55:07<00:00, 12094.88it/s]
# DataFrameを作成
# スプリット列を追加
# get_coin列の追加
# Wall time: 3h 9min 29s

# %%
b = abj.WinPercentage(df)
j, k = b.win_percentage(split=300, plot=True)
# Out:
# 49.68218%

# %%
#1oo点に分けてプロット
b = abj.WinPercentage(df)
j, k = b.win_percentage(split=100, plot=True)
# Out:
# 49.6825%

# %%
#1000点に分けてプロット
b = abj.WinPercentage(df)
j, k = b.win_percentage(split=1000, plot=True)
# Out:
# 49.6825%
