# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
import sys
#"".."からimportできなかったため，パスを追加．
module_path = os.path.abspath(os.path.join('../analysis'))
if module_path not in sys.path:
    sys.path.append(module_path)

import analysis_black_jack as abj

# %% [markdown]
# ## ブラックジャックの実行（40000000回）

# %%
# %%time
a = abj.MakeDataFrame(30000000, 5, True, 100)
df = a.main()
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 30000000/30000000 [35:18<00:00, 14162.72it/s]
# DataFrameを作成
# スプリット列を追加
# get_coin列の追加
# Wall time: 1h 57min 11s

# %% [markdown]
# ### 勝率の推移．勝率は収束していく

# %%
b = abj.AnalysisDf(df)
j, k = b.win_percentage(split=1000, plot=True)
# Out:
# 49.52%

# %% [markdown]
# ## ブラックジャックの実行（40000000回）

# %%
# %%time
a = abj.MakeDataFrame(40000000, 5, True, 100)
df = a.main()
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 40000000/40000000 [55:07<00:00, 12094.88it/s]
# DataFrameを作成
# スプリット列を追加
# get_coin列の追加
# Wall time: 3h 9min 29s

# %%
b = abj.AnalysisDf(df)
j, k = b.win_percentage(split=1000, plot=True)
# Out:
# 49.385%

# %%
#1oo点に分けてプロット
b = abj.AnalysisDf(df)
j, k = b.win_percentage(split=100, plot=True)
# Out:
# 49.385%

# %%
#10000点に分けてプロット
b = abj.AnalysisDf(df)
j, k = b.win_percentage(split=10000, plot=True)
# Out:
# 49.385%
